# %% [markdown]
# # **Instructions**:
#
# ### 1 - Open your game that you want to perform detections
# ### 2 - In the game window, get the name of it's title bar
# ### 3 - Update the variable "window_name" with the game title bar name
# ### 4 - Run all cells to start detecting objects using your trained model

# %%
pip install mss
# Out:
# Collecting mss
#   Downloading mss-9.0.2-py3-none-any.whl.metadata (6.1 kB)
# Downloading mss-9.0.2-py3-none-any.whl (23 kB)
# Installing collected packages: mss
# Successfully installed mss-9.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import win32gui, win32ui, win32con
from PIL import Image
from time import sleep
from ctypes import windll
import cv2 as cv
import os
import random
import mss

# %%
class WindowCapture:
    w = 0
    h = 0
    hwnd = None
    monitor = None

    def __init__(self, window_name):
        self.hwnd = win32gui.FindWindow(None, window_name)
        if not self.hwnd:
            raise Exception('Window not found: {}'.format(window_name))

        # Get the window's rectangle (left, top, right, bottom)
        window_rect = win32gui.GetWindowRect(self.hwnd)
        self.w = window_rect[2] - window_rect[0]  # Width
        self.h = window_rect[3] - window_rect[1]  # Height

        # Define the border and title bar size
        border_pixels = 8
        titlebar_pixels = 30

        # Adjust the width and height, subtracting borders and title bar
        self.w = self.w - (border_pixels * 2)
        self.h = self.h - titlebar_pixels - border_pixels

        # Make sure width and height are non-negative
        if self.w <= 0 or self.h <= 0:
            raise ValueError(f"Calculated dimensions are invalid: width={self.w}, height={self.h}")

        # Set the top-left corner for the monitor region
        self.cropped_x = window_rect[0] + border_pixels
        self.cropped_y = window_rect[1] + titlebar_pixels

        # Setup the monitor region to capture
        self.monitor = {
            "top": self.cropped_y,
            "left": self.cropped_x,
            "width": self.w,
            "height": self.h
        }

    def get_screenshot(self):
        with mss.mss() as sct:
            screenshot = sct.grab(self.monitor)
            img = np.array(screenshot)  # Convert to numpy array

            # Convert to OpenCV's BGR format
            img = cv.cvtColor(img, cv.COLOR_RGBA2BGR)

            return img

    def generate_image_dataset(self):
        if not os.path.exists("images"):
            os.mkdir("images")
        while(True):
            img = self.get_screenshot()
            im = Image.fromarray(img[..., [2, 1, 0]])
            im.save(f"./images/img_{len(os.listdir('images'))}.jpeg")
            sleep(1)
    
    def get_window_size(self):
        return (self.w, self.h)

# %%
class ImageProcessor:
    W = 0
    H = 0
    net = None
    ln = None
    classes = {}
    colors = []

    def __init__(self, img_size, cfg_file, weights_file):
        np.random.seed(42)
        self.net = cv.dnn.readNetFromDarknet(cfg_file, weights_file)
        self.net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
        self.ln = self.net.getLayerNames()
        self.ln = [self.ln[i-1] for i in self.net.getUnconnectedOutLayers()]
        self.W = img_size[0]
        self.H = img_size[1]
        
        with open('yolov4-tiny/obj.names', 'r') as file:
            lines = file.readlines()
        for i, line in enumerate(lines):
            self.classes[i] = line.strip()
        
        # If you plan to utilize more than six classes, please include additional colors in this list.
        self.colors = [
            (0, 0, 255), 
            (0, 255, 0), 
            (255, 0, 0), 
            (255, 255, 0), 
            (255, 0, 255), 
            (0, 255, 255)
        ]
        

    def proccess_image(self, img):

        blob = cv.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
        self.net.setInput(blob)
        outputs = self.net.forward(self.ln)
        outputs = np.vstack(outputs)
        
        coordinates = self.get_coordinates(outputs, 0.5)

        self.draw_identified_objects(img, coordinates)

        return coordinates

    def get_coordinates(self, outputs, conf):

        boxes = []
        confidences = []
        classIDs = []

        for output in outputs:
            scores = output[5:]
            
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > conf:
                x, y, w, h = output[:4] * np.array([self.W, self.H, self.W, self.H])
                p0 = int(x - w//2), int(y - h//2)
                boxes.append([*p0, int(w), int(h)])
                confidences.append(float(confidence))
                classIDs.append(classID)

        indices = cv.dnn.NMSBoxes(boxes, confidences, conf, conf-0.1)

        if len(indices) == 0:
            return []

        coordinates = []
        for i in indices.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            coordinates.append({'x': x, 'y': y, 'w': w, 'h': h, 'class': classIDs[i], 'class_name': self.classes[classIDs[i]]})
        return coordinates

    def draw_identified_objects(self, img, coordinates):
        for coordinate in coordinates:
            x = coordinate['x']
            y = coordinate['y']
            w = coordinate['w']
            h = coordinate['h']
            classID = coordinate['class']
            
            color = self.colors[classID]
            
            cv.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv.putText(img, self.classes[classID], (x, y - 10), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        cv.imshow('window',  img)

# %%
# Run this cell to initiate detections using the trained model.

window_name = "Galaxy Life"
cfg_file_name = "./yolov4-tiny/yolov4-tiny-custom.cfg"
weights_file_name = "yolov4-tiny-custom_last.weights"

wincap = WindowCapture(window_name)
improc = ImageProcessor(wincap.get_window_size(), cfg_file_name, weights_file_name)

while(True):
    
    ss = wincap.get_screenshot()
    
    if cv.waitKey(1) == ord('q'):
        cv.destroyAllWindows()
        break

    coordinates = improc.proccess_image(ss)
    
    for coordinate in coordinates:
        print(coordinate)
    print()
    
    # If you have limited computer resources, consider adding a sleep delay between detections.
    sleep(1)

print('Finished.')
# Out:
# {'x': 402, 'y': 199, 'w': 54, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 423, 'y': 669, 'w': 54, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 289, 'y': 511, 'w': 46, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 87, 'y': 528, 'w': 55, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 861, 'w': 37, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 255, 'y': 345, 'w': 46, 'h': 47, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 433, 'y': 375, 'w': 64, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 122, 'y': 745, 'w': 74, 'h': 66, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 816, 'y': 220, 'w': 44, 'h': 43, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 867, 'y': 956, 'w': 66, 'h': 43, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 347, 'y': 578, 'w': 54, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 575, 'y': 664, 'w': 57, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 257, 'w': 52, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 770, 'y': 657, 'w': 67, 'h': 69, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 30, 'y': 111, 'w': 58, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 349, 'y': 434, 'w': 58, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 191, 'y': 689, 'w': 58, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 193, 'y': 146, 'w': 42, 'h': 44, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 224, 'y': 305, 'w': 46, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 821, 'y': 507, 'w': 64, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 364, 'y': 148, 'w': 59, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 40, 'y': 475, 'w': 72, 'h': 65, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 348, 'y': 577, 'w': 52, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 575, 'y': 664, 'w': 56, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 350, 'y': 435, 'w': 57, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 257, 'w': 52, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 770, 'y': 657, 'w': 67, 'h': 69, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 30, 'y': 111, 'w': 58, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 192, 'y': 688, 'w': 57, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 193, 'y': 146, 'w': 42, 'h': 44, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 224, 'y': 306, 'w': 46, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 821, 'y': 507, 'w': 64, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 364, 'y': 148, 'w': 59, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 40, 'y': 474, 'w': 72, 'h': 66, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 247, 'y': 577, 'w': 59, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 253, 'y': 436, 'w': 52, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 130, 'y': 307, 'w': 43, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 269, 'y': 152, 'w': 52, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 476, 'y': 667, 'w': 55, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 101, 'y': 693, 'w': 44, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 668, 'y': 658, 'w': 74, 'h': 72, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 100, 'y': 152, 'w': 36, 'h': 37, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 718, 'y': 506, 'w': 72, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 471, 'w': 13, 'h': 74, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 247, 'y': 579, 'w': 56, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 253, 'y': 437, 'w': 54, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 270, 'y': 152, 'w': 51, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 130, 'y': 308, 'w': 43, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 476, 'y': 667, 'w': 54, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 668, 'y': 658, 'w': 74, 'h': 72, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 101, 'y': 691, 'w': 45, 'h': 50, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 100, 'y': 152, 'w': 36, 'h': 37, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 718, 'y': 506, 'w': 72, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 473, 'w': 13, 'h': 72, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 348, 'y': 577, 'w': 52, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 575, 'y': 664, 'w': 56, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 350, 'y': 435, 'w': 57, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 770, 'y': 657, 'w': 67, 'h': 69, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 31, 'y': 110, 'w': 57, 'h': 63, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 192, 'y': 688, 'w': 57, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 195, 'y': 147, 'w': 41, 'h': 44, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 6, 'y': 257, 'w': 51, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 821, 'y': 507, 'w': 64, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 224, 'y': 305, 'w': 46, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 364, 'y': 148, 'w': 59, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 40, 'y': 475, 'w': 73, 'h': 65, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 659, 'y': 529, 'w': 63, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 260, 'y': 337, 'w': 61, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 144, 'y': 217, 'w': 50, 'h': 48, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 470, 'y': 548, 'w': 59, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 258, 'y': 480, 'w': 56, 'h': 50, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 114, 'y': 599, 'w': 55, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 263, 'y': 799, 'w': 52, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 698, 'y': 377, 'w': 72, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 355, 'w': 7, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 499, 'y': 528, 'w': 59, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 328, 'y': 548, 'w': 57, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 34, 'y': 215, 'w': 47, 'h': 48, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 135, 'y': 335, 'w': 60, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 537, 'y': 377, 'w': 70, 'h': 63, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 131, 'y': 477, 'w': 56, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 12, 'y': 69, 'w': 40, 'h': 36, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 600, 'w': 49, 'h': 47, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 139, 'y': 796, 'w': 53, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 895, 'w': 52, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 877, 'y': 354, 'w': 55, 'h': 50, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 500, 'y': 531, 'w': 59, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 136, 'y': 339, 'w': 58, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 131, 'y': 479, 'w': 56, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 34, 'y': 218, 'w': 46, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 602, 'w': 49, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 138, 'y': 797, 'w': 54, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 898, 'w': 52, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 12, 'y': 69, 'w': 41, 'h': 38, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 535, 'y': 379, 'w': 74, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 883, 'y': 66, 'w': 50, 'h': 39, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 499, 'y': 531, 'w': 60, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 136, 'y': 339, 'w': 58, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 131, 'y': 480, 'w': 57, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 34, 'y': 218, 'w': 46, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 326, 'y': 551, 'w': 60, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 601, 'w': 49, 'h': 50, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 536, 'y': 379, 'w': 75, 'h': 63, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 138, 'y': 797, 'w': 54, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 898, 'w': 52, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 12, 'y': 69, 'w': 41, 'h': 38, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 883, 'y': 66, 'w': 50, 'h': 39, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 499, 'y': 531, 'w': 60, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 136, 'y': 339, 'w': 58, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 131, 'y': 480, 'w': 57, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 34, 'y': 218, 'w': 46, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 326, 'y': 551, 'w': 60, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 601, 'w': 49, 'h': 50, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 536, 'y': 379, 'w': 75, 'h': 63, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 138, 'y': 797, 'w': 54, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 898, 'w': 52, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 12, 'y': 69, 'w': 41, 'h': 38, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 883, 'y': 66, 'w': 50, 'h': 39, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 499, 'y': 532, 'w': 60, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 136, 'y': 339, 'w': 58, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 131, 'y': 480, 'w': 57, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 34, 'y': 218, 'w': 46, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 326, 'y': 551, 'w': 59, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 3, 'y': 602, 'w': 49, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 535, 'y': 380, 'w': 75, 'h': 63, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 138, 'y': 797, 'w': 54, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 898, 'w': 52, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 12, 'y': 69, 'w': 41, 'h': 38, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 883, 'y': 66, 'w': 50, 'h': 39, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 470, 'y': 532, 'w': 65, 'h': 66, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 16, 'y': 218, 'w': 47, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 303, 'y': 551, 'w': 60, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 600, 'w': 35, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 68, 'w': 36, 'h': 40, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 115, 'y': 338, 'w': 60, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 111, 'y': 481, 'w': 58, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 113, 'y': 798, 'w': 56, 'h': 57, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 507, 'y': 381, 'w': 78, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': -1, 'y': 899, 'w': 36, 'h': 43, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 865, 'y': 66, 'w': 50, 'h': 38, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 261, 'y': 833, 'w': 64, 'h': 40, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 439, 'y': 532, 'w': 68, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 219, 'w': 43, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 91, 'y': 481, 'w': 53, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 552, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 65, 'w': 13, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 93, 'y': 339, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 602, 'w': 13, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 897, 'w': 12, 'h': 48, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 475, 'y': 378, 'w': 75, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 94, 'y': 802, 'w': 51, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 439, 'y': 532, 'w': 68, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 219, 'w': 43, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 91, 'y': 481, 'w': 53, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 552, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 65, 'w': 13, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 93, 'y': 339, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 602, 'w': 13, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 897, 'w': 12, 'h': 48, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 475, 'y': 378, 'w': 75, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 94, 'y': 802, 'w': 51, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 439, 'y': 532, 'w': 68, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 219, 'w': 43, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 91, 'y': 481, 'w': 53, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 552, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 65, 'w': 13, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 93, 'y': 339, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 602, 'w': 13, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 897, 'w': 12, 'h': 48, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 475, 'y': 378, 'w': 75, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 94, 'y': 802, 'w': 51, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 439, 'y': 532, 'w': 69, 'h': 71, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 219, 'w': 43, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 91, 'y': 482, 'w': 53, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 277, 'y': 552, 'w': 59, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 65, 'w': 13, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 93, 'y': 339, 'w': 59, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 602, 'w': 13, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 897, 'w': 12, 'h': 48, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 475, 'y': 378, 'w': 75, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 94, 'y': 802, 'w': 51, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 132, 'y': 644, 'w': 57, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 722, 'y': 135, 'w': 48, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 638, 'w': 63, 'h': 69, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 137, 'w': 47, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 883, 'w': 15, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 416, 'w': 22, 'h': 58, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 316, 'y': 487, 'w': 67, 'h': 63, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 563, 'w': 16, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 131, 'y': 644, 'w': 56, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 721, 'y': 138, 'w': 48, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 638, 'w': 62, 'h': 70, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 139, 'w': 47, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 884, 'w': 14, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 317, 'y': 492, 'w': 65, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 418, 'w': 23, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 565, 'w': 17, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 717, 'y': 434, 'w': 53, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 131, 'y': 644, 'w': 56, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 721, 'y': 138, 'w': 48, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 638, 'w': 62, 'h': 70, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 139, 'w': 47, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 884, 'w': 14, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 317, 'y': 492, 'w': 65, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 418, 'w': 23, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 565, 'w': 17, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 717, 'y': 434, 'w': 53, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 131, 'y': 644, 'w': 56, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 721, 'y': 138, 'w': 48, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 638, 'w': 62, 'h': 70, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 139, 'w': 47, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 884, 'w': 14, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 317, 'y': 492, 'w': 65, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 418, 'w': 23, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 565, 'w': 17, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 717, 'y': 434, 'w': 53, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 131, 'y': 644, 'w': 56, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 721, 'y': 138, 'w': 48, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 278, 'y': 638, 'w': 62, 'h': 70, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 139, 'w': 47, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 884, 'w': 14, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 317, 'y': 492, 'w': 65, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 418, 'w': 23, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 565, 'w': 17, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 717, 'y': 434, 'w': 53, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 131, 'y': 647, 'w': 57, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 722, 'y': 137, 'w': 46, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 140, 'w': 45, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 276, 'y': 641, 'w': 66, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 419, 'w': 21, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 880, 'w': 12, 'h': 60, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 564, 'w': 14, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 315, 'y': 492, 'w': 68, 'h': 60, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 131, 'y': 647, 'w': 57, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 722, 'y': 137, 'w': 46, 'h': 46, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 140, 'w': 45, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 276, 'y': 641, 'w': 66, 'h': 67, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 419, 'w': 21, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 880, 'w': 12, 'h': 60, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 564, 'w': 14, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 315, 'y': 492, 'w': 68, 'h': 60, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 133, 'y': 646, 'w': 54, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 279, 'y': 639, 'w': 61, 'h': 68, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 723, 'y': 139, 'w': 46, 'h': 43, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 139, 'w': 46, 'h': 49, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 318, 'y': 492, 'w': 62, 'h': 60, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 718, 'y': 435, 'w': 49, 'h': 50, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 883, 'w': 14, 'h': 54, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 565, 'w': 15, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 419, 'w': 20, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 132, 'y': 645, 'w': 56, 'h': 55, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 721, 'y': 138, 'w': 48, 'h': 45, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 277, 'y': 638, 'w': 62, 'h': 70, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 1, 'y': 139, 'w': 47, 'h': 51, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 884, 'w': 14, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 316, 'y': 492, 'w': 66, 'h': 62, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 418, 'w': 23, 'h': 56, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 0, 'y': 565, 'w': 17, 'h': 53, 'class': np.int64(0), 'class_name': 'star system'}
# {'x': 717, 'y': 434, 'w': 53, 'h': 52, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 634, 'y': 806, 'w': 17, 'h': 29, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 634, 'y': 806, 'w': 17, 'h': 29, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 634, 'y': 807, 'w': 17, 'h': 29, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 548, 'y': 793, 'w': 25, 'h': 47, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 634, 'y': 806, 'w': 17, 'h': 29, 'class': np.int64(0), 'class_name': 'star system'}
#
# {'x': 633, 'y': 806, 'w': 17, 'h': 29, 'class': np.int64(0), 'class_name': 'star system'}
# KeyboardInterrupt
